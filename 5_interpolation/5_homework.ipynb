# %% [markdown]
# # Домашняя работа. Интерполяция

# %% [markdown]
# Даны точки.
#
# ```
# [0.000000, 1.250000],
# [1.000000, 1.116472],
# [2.500000, 0.247223],
# [3.000000, -0.079148],
# [5.000000, -0.523167]```
#
# 1. Построить по этим точкам два интерполяционных полинома и сплайн интерполяцию степени k (по вариантам).
#
# 2. Построить графики этих функций.
#
# 3. Вычислить значение функций в точках с х координатами: 0.5, 4, -1, 10.
#
# Объясните полученные результаты. Можно ли вычислить значения сплайнов вне отрезка от 0 до 5? Почему?

# %% [markdown]
# | Вариант | Полином 1 | Полином 2 | Степень k сплайна |
# |:----:|:----|:-----|:----:|
# | 1 | степенной | Чебышева | 3 |
# | 2 | Чебышева | Лагранжа | 2 |
# | 3 | Лагранжа | Лаггера | 1 |
# | 4 | Лаггера | Эрмита (физический) | 3 |
# | 5 | Эрмита (физический) | Эрмита (вероятностный) | 2 |
# | 6 | Эрмита (вероятностный) | Чебышева | 1 |

# %% [markdown]
# ![](https://raw.githubusercontent.com/tatyderb/m2020/master/5_interpolation/img/intepol_zoom.png)

# %% [markdown]
# ```
# Точные значения:
# f(0.5) = 1.240999216492717
# f(4.0) = -0.52533551794138922
# f(-1)  = 0.96425476967335877
# f(10)  = 0.31766764161830657
#
# --------------------------------------
# Polynomial
# poly([ 0.24722264 -1.67934211  0.07734977  0.79275858  0.03884406])
# f(0.500000) =  1.25021831319
# f(4.000000) =  -0.556266664783
# f(-1.000000) =  0.723800947171
# f(10.000000) =  20.4561946548
# --------------------------------------
# Chebyshev
# cheb([ 0.30046405 -1.08477317  0.05809692  0.19818964  0.00485551])
# f(0.500000) =  1.25021831319
# f(4.000000) =  -0.556266664783
# f(-1.000000) =  0.723800947171
# f(10.000000) =  20.4561946548
# --------------------------------------
# Legendre
# leg([ 0.28077471 -1.20368696  0.07376312  0.31710343  0.00887864])
# f(0.500000) =  1.25021831319
# f(4.000000) =  -0.556266664783
# f(-1.000000) =  0.723800947171
# f(10.000000) =  20.4561946548
# --------------------------------------
# Laguerre
# lag([  30.99529403 -119.13946251  164.73687759  -90.2588281    14.91611899])
# f(0.500000) =  1.25021831319
# f(4.000000) =  -0.556266664783
# f(-1.000000) =  0.723800947171
# f(10.000000) =  20.4561946547
# --------------------------------------
# Hermite
# herm([ 0.31503057 -0.24510212  0.04847049  0.09909482  0.00242775])
# f(0.500000) =  1.25021831319
# f(4.000000) =  -0.556266664783
# f(-1.000000) =  0.723800947171
# f(10.000000) =  20.4561946548
# --------------------------------------
# HermiteE
# herme([ 0.44110459  0.69893362  0.31041413  0.79275858  0.03884406])
# f(0.500000) =  1.25021831319
# f(4.000000) =  -0.556266664783
# f(-1.000000) =  0.723800947171
# f(10.000000) =  20.4561946548
# spline(2):
# s(0.500000) =  1.1832360788627692
# s(4.000000) =  -0.3011573165735435
# spline(3):
# s(0.500000) =  1.2617330912032743
# s(4.000000) =  -0.48715113354782824
# spline(4):
# s(0.500000) =  1.251134003242776
# s(4.000000) =  -0.5565249252458007
# ```
