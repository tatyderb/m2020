# %% [markdown]
# Урок 1. Часть 1. Построение простого графика.
#
# Линии, оси, заголовки, подписи к графикам.
# Разные типы графиков.

# %% [markdown]
# # Полезные ссылки
#
#
# * cheat sheet
#   * [Python_Matplotlib_Cheat_Sheet.pdf](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf) from DataCamp
# * acm.mipt.ru
#   * [как работать в notebook](http://acm.mipt.ru/twiki/bin/view/Cintro/PythonNotebook)
#   * [Построение графиков в Python](http://acm.mipt.ru/twiki/bin/view/Cintro/PythonGraphs)
#   * [Задачи урока](http://acm.mipt.ru/twiki/bin/view/Cintro/PythonPyplot) - старые
# * Tutorials
#   * [Colab](https://colab.research.google.com/notebooks/charts.ipynb#scrollTo=QSMmdrrVLZ-N)
#   * [https://github.com/rougier/matplotlib-tutorial](https://github.com/rougier/matplotlib-tutorial) by N.Roger
#     * [Youtube](https://www.youtube.com/watch?v=q7Bo_J8x_dw&list=PLQVvvaa0QuDfefDfXb9Yf0la1fPDKluPF) - 32 урока
#   * [Научная графика в Python](https://nbviewer.jupyter.org/github/whitehorn/Scientific_graphics_in_python/blob/master/P1%20Chapter%201%20Pyplot.ipynb)
# * Официальная документация:
#   * [Примеры matplotlib.org](http://matplotlib.org/examples/index.html)

# %% [markdown]
# # Зачем нужна визуализация данных
#
# ## Визуализация на сайте
#
# [https://www.gapminder.org/](https://www.gapminder.org/)
#
# ## Средняя продолжительность жизни в зависимости от дохода страны на 1 человека
#
# [countries_health_wealth_2016.pdf](https://s3-eu-west-1.amazonaws.com/static.gapminder.org/GapminderMedia/wp-uploads/20161215212516/countries_health_wealth_2016_v151.pdf)

# %% [markdown]
# ## График населения Земли в зависимости от времени

# %%
import matplotlib.pyplot as plt

year = [1950, 1970, 1990, 2010]     # year       
pop = [2.519, 3.692, 5.263, 6.972]  # population, billions 

plt.plot(year, pop)

# назвали оси
plt.xlabel('Год')
plt.ylabel('Население Земли, миллион человек')
# Out:
# Text(0, 0.5, 'Население Земли, миллион человек')

# %% [markdown]
# Вопрос: Как вы думаете, к какому году на Земле будет 10 миллиардов человек, если население будет так же расти?
#
# Ответ:

# %% [markdown]
# # График точками

# %% [markdown]
# Мы уже один раз сказали
#
# ```
# import matplotlib.pyplot as plt
# ```
# Это действует до конца файла.
#
# Если работать тут, то не надо писать.
#
# ```
# plt.show()
# ```
# Пример графика точками:

# %%
year = [1950, 1970, 1990, 2010]     # year       
pop = [2.519, 3.692, 5.263, 6.972]  # population, billions 

plt.scatter(year, pop)

# %% [markdown]
# # Как это работает?

# %% [markdown]
# Строятся точки $(x_0, y_0), (x_1, y_1) .. (x_n, y_n)$  и соединяются линиями в функции plot()
# ![plot.png](data:image/png;base64,...)

# %% [markdown]
# # Простой график
#
# ## Шаг 1. Точки и plot
#
# Построим графики фукнкций $sin(x)$ и $cos(x)$
#
# Будем улучшать график постепенно.
#
# Сначала нужно построить точки Х и У. Можно задать как раньше, а можно через библиотеку numpy
#
# ```
# import numpy as np
#
# X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
# CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.plot(X, CY)
plt.plot(X, SY)

plt.show()

# %% [markdown]
# Изменим цвет, ширину и стиль линий графиков.
# ```
# plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная
# plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-")
# plt.plot(X, S, color="red",  linewidth=5, linestyle=".")
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная
plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.")

plt.show()

# %% [markdown]
# ## Границы по х и у
#
# Рисовать от хmin до хmax можно командой
#
#
# ```
# plt.xlim(xmin, xmax)
# ```
#
# Можно найти в векторе минимальное и максимальное значение `CY.min()` и `CY.max()`
#
# и выставить границы так:
# ```
# plt.xlim(X.min()*1.1, X.max()*1.1)
# plt.ylim(CY.min()*1.1, CY.max()*1.1)
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная

# диапазон по х и у
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(CY.min()*1.1, CY.max()*1.1)

plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.")

plt.show()

# %% [markdown]
# ## Поставим черточки на шкалах (ticks)
#
# Хотим поставить черточки на шкалах и подписать значения не в -3, -2, -1, 0, 1, 2, 3 на оси Х, а в $-{\pi},  -\pi/2, 0, \pi/2, \pi$
#
# ```
# plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
# plt.yticks([-1, 0, +1])
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная

# диапазон по х и у
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(CY.min()*1.1, CY.max()*1.1)

# ставим черточки на осях
plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])


plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.")

plt.show()

# %% [markdown]
# ## Подписи хотим красивые, c $\pi$, а не -3.142
#
# Перечислим список подписей **такой же длины**, что и список черточек. Если не совпадут размеры, будет ошибка.
#
# ```
# plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],
#        [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная

# диапазон по х и у
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(CY.min()*1.1, CY.max()*1.1)

# ставим черточки на осях
plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

# подписи с pi на оси Х
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.")

plt.show()

# %% [markdown]
# ## Рисуем оси в правильном месте, а не сверху и снизу
#
# В математике принято рисовать оси Х и У через 0. Нарисуем их так.
#
# Обычно в ваших графиках это делать не нужно.
#
# Осей на самом деле было нарисовано 4: right, left, top, bottom.
#
# Сделаем оси right и top невидимыми.
#
# Оси left и bottom передвинем в 0.
#
# ```
# ax = plt.gca()                          # взять оси графика
# ax.spines['right'].set_color('none')    # сделать ось right невидимой
# ax.spines['top'].set_color('none')      # сделать ось top невидимой
# ax.xaxis.set_ticks_position('bottom')   # взять черточки для осих Х с оси bottom
# ax.spines['bottom'].set_position(('data',0))
# ax.yaxis.set_ticks_position('left')     # взять черточки для осих Y с оси left
# ax.spines['left'].set_position(('data',0))
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная

# диапазон по х и у
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(CY.min()*1.1, CY.max()*1.1)

# ставим черточки на осях
plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

# подписи с pi на оси Х
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

# Передвигаем оси так, чтобы они шли через (0,0)
ax = plt.gca()                          # взять оси графика
ax.spines['right'].set_color('none')    # сделать ось right невидимой
ax.spines['top'].set_color('none')      # сделать ось top невидимой
ax.xaxis.set_ticks_position('bottom')   # взять черточки для осих Х с оси bottom
ax.spines['bottom'].set_position(('data',0))  # поставись ось bottom в точку 0
ax.yaxis.set_ticks_position('left')     # взять черточки для осих Y с оси left
ax.spines['left'].set_position(('data',0))    # поставись ось left в точку 0

plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.")

plt.show()

# %% [markdown]
# ## Добавим легенду (что значит какая линия)
#
# Я не понимаю, что значит синяя и красная линии. Нужно объяснить.
#
# Подпишем, что синяя линия это косинус, а красная - синус.
#
# Для этого в `plot` добавим аргумент `label` и скажем, что легенду нужно показать.
#
# ```
# plt.legend(loc='upper left', frameon=False)
# ```
# Получилось:

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная

# диапазон по х и у
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(CY.min()*1.1, CY.max()*1.1)

# ставим черточки на осях
plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

# подписи с pi на оси Х
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

# Передвигаем оси так, чтобы они шли через (0,0)
ax = plt.gca()                          # взять оси графика
ax.spines['right'].set_color('none')    # сделать ось right невидимой
ax.spines['top'].set_color('none')      # сделать ось top невидимой
ax.xaxis.set_ticks_position('bottom')   # взять черточки для осих Х с оси bottom
ax.spines['bottom'].set_position(('data',0))  # поставись ось bottom в точку 0
ax.yaxis.set_ticks_position('left')     # взять черточки для осих Y с оси left
ax.spines['left'].set_position(('data',0))    # поставись ось left в точку 0

plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-", label="косинус")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.", label="синус")

# рисуем легенду в левом верхнем углу без рамочки
plt.legend(loc='upper left', frameon=False)

plt.show()

# %% [markdown]
# ## Название графика (title)
#
# О чем этот график, нужно его назвать.
#
# Добавим title. Он добавляется прямо ко всей figure.
#
# Сделем шрифт графика побольше, `fonsize=20`
#
# ```
# plt.title("Графики синуса и косинуса", fontsize=20)
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная
plt.title("Графики синуса и косинуса", fontsize=20)

# диапазон по х и у
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(CY.min()*1.1, CY.max()*1.1)

# ставим черточки на осях
plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

# подписи с pi на оси Х
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

# Передвигаем оси так, чтобы они шли через (0,0)
ax = plt.gca()                          # взять оси графика
ax.spines['right'].set_color('none')    # сделать ось right невидимой
ax.spines['top'].set_color('none')      # сделать ось top невидимой
ax.xaxis.set_ticks_position('bottom')   # взять черточки для осих Х с оси bottom
ax.spines['bottom'].set_position(('data',0))  # поставись ось bottom в точку 0
ax.yaxis.set_ticks_position('left')     # взять черточки для осих Y с оси left
ax.spines['left'].set_position(('data',0))    # поставись ось left в точку 0

plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-", label="косинус")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.", label="синус")

# рисуем легенду в левом верхнем углу без рамочки
plt.legend(loc='upper left', frameon=False)

plt.show()

# %% [markdown]
# ## Решетка (grid)
#
# ```
# plt.grid()
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная
plt.title("Графики синуса и косинуса", fontsize=20)

# диапазон по х и у
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(CY.min()*1.1, CY.max()*1.1)

# ставим черточки на осях
plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

# подписи с pi на оси Х
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

# Передвигаем оси так, чтобы они шли через (0,0)
ax = plt.gca()                          # взять оси графика
ax.spines['right'].set_color('none')    # сделать ось right невидимой
ax.spines['top'].set_color('none')      # сделать ось top невидимой
ax.xaxis.set_ticks_position('bottom')   # взять черточки для осих Х с оси bottom
ax.spines['bottom'].set_position(('data',0))  # поставись ось bottom в точку 0
ax.yaxis.set_ticks_position('left')     # взять черточки для осих Y с оси left
ax.spines['left'].set_position(('data',0))    # поставись ось left в точку 0

plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-", label="косинус")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.", label="синус")

# рисуем легенду в левом верхнем углу без рамочки
plt.legend(loc='upper left', frameon=False)
plt.grid()

plt.show()

# %% [markdown]
# ### Сделаем буквы для tick labels побольше
#
# Переберем список для tick labels
#
# ```
# for label in ax.get_xticklabels() + ax.get_yticklabels():
#     label.set_fontsize(16)
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

X = np.linspace(-np.pi, np.pi, 256, endpoint=True) # 258 точек от -пи до пи, включая последнюю, вектор Х
CY, SY = np.cos(X), np.sin(X)                      # векторы Y координат для cos и sin

plt.figure(figsize=(10,6), dpi=80)   # размер фигуры 10 к 6, более горизонтальная
plt.title("Графики синуса и косинуса", fontsize=20)

# диапазон по х и у
plt.xlim(X.min()*1.1, X.max()*1.1)
plt.ylim(CY.min()*1.1, CY.max()*1.1)

# ставим черточки ticks на осях и подписываем label у черточки
plt.xticks( [-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0, +1])

# подписи с pi на оси Х
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi], [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

# Передвигаем оси так, чтобы они шли через (0,0)
ax = plt.gca()                          # взять оси графика
ax.spines['right'].set_color('none')    # сделать ось right невидимой
ax.spines['top'].set_color('none')      # сделать ось top невидимой
ax.xaxis.set_ticks_position('bottom')   # взять черточки для осих Х с оси bottom
ax.spines['bottom'].set_position(('data',0))  # поставись ось bottom в точку 0
ax.yaxis.set_ticks_position('left')     # взять черточки для осих Y с оси left
ax.spines['left'].set_position(('data',0))    # поставись ось left в точку 0

for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)

plt.plot(X, CY, color="blue", linewidth=2.5, linestyle="-", label="косинус")
plt.plot(X, SY, color="red",  linewidth=5, linestyle="-.", label="синус")

# рисуем легенду в левом верхнем углу без рамочки
plt.legend(loc='upper left', frameon=False)

plt.grid()

plt.show()

# %% [markdown]
# ## Сохранить картинку в файл plt.savefig(file="picture.png")
#
# Указываем имя файла, расширения png, jpg, svg
#
# ```
# plt.savefig(file="picture.png")
# plt.savefig(file="picture2.svg", )
# save('pic_10_4_1', fmt='pdf')
# ```

# %% [markdown]
# ## Оси
#
# ### Логарифмическая ось xscale и yscale
#
# Чтобы понять, чем отличаются логарифмические оси рассмотрим графики функций $y=x$ и $y = e^x$ и $y=10^x$

# %%
x = np.linspace(0, 5, 100)
y1 = x
y2 = np.exp(x)
y3 = 10**x

plt.figure(figsize=(6, 2))

plt.subplot(1, 2, 1)
plt.ylim(0, 20)
plt.plot(x, y1, label='x')
plt.plot(x, y2, label=r'$e^x$')
plt.plot(x, y3, label=r'$10^x$')
plt.title('Linear')
plt.legend()

plt.subplot(1, 2, 2)
plt.yscale('log')
plt.plot(x, y1, label='x')
plt.plot(x, y2, label=r'$e^x$')
plt.plot(x, y3, label=r'$10^x$')
plt.title('log')

plt.savefig("picture.png")
plt.savefig("picture2.svg", transparent=True)

# %% [markdown]
# ### Одинаковый масштаб по оси Х и Y

# %% [markdown]
# ## Параметрически заданный график
#
# Хотим напечатать окружность радиуса R=3 с центром в точке (0,0). Какой это график?
#
# Мы будем рисовать точки (x,y) по кругу. Сначала (0,R), потом каждый раз поворачиваясь на $da$ градусов. Если уже повернулись на $a$ градусов, какие х и y у точки?
#
# <img src="http://fizmat.by/pic/MATH/page321/im3.jpg" width=300 height=300 />
#
# Тогда для угла $a$ у нас будет $x = R cos(a), y = R sin(a)$.
#
# Чтобы пройти все точки на окружности, $a$ должно меняться от 0 до $2\pi$
#
# Говорят, что окружность задана параметрически, т.е. x(a) и y(a)

# %%
import numpy as np
import matplotlib.pyplot as plt

# задаем список точек
R = 3
a = np.linspace(0, 2*np.pi, 100)
x = R * np.cos(a)
y = R * np.sin(a)

fig, ax = plt.subplots()
ax.set_aspect('equal')    # одинаковый масштаб по х и у, иначе овал, а не круг
ax.plot(x, y)
